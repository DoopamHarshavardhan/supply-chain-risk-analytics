# %%
pip install pandas matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_csv("../data/cleaned_supply_chain.csv")

df.head()
# Out:
#    Order Id     Type     Order Status  order_date shipping_date  \
# 0         1    DEBIT          PENDING  2015-04-13    2015-04-16
# 1         2     CASH          ON_HOLD  2016-03-11    2016-03-13
# 2         3     CASH  SUSPECTED_FRAUD  2017-05-10    2017-05-16
# 3         4  PAYMENT         COMPLETE  2015-09-28    2015-10-04
# 4         5     CASH  SUSPECTED_FRAUD  2015-04-17    2015-04-19
#
#    Days for shipping (real)  Days for shipment (scheduled)  delivery_delay  \
# 0                         3                              4              -1
# 1                         2                              3              -1
# 2                         6                              3               3
# 3                         6                              4               2
# 4                         2                              3              -1
#
#    is_late    Delivery Status  ...  Customer Id Customer Segment  \
# ...

# %%
df.shape

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 36 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Order Id                       500 non-null    int64
#  1   Type                           500 non-null    object
#  2   Order Status                   500 non-null    object
#  3   order_date                     500 non-null    object
#  4   shipping_date                  500 non-null    object
#  5   Days for shipping (real)       500 non-null    int64
#  6   Days for shipment (scheduled)  500 non-null    int64
#  7   delivery_delay                 500 non-null    int64
#  8   is_late                        500 non-null    int64
#  9   Delivery Status                500 non-null    object
#  10  Late_delivery_risk             500 non-null    int64
#  11  Shipping Mode                  500 non-null    object
# ...

# %%
df['delivery_delay'].describe()
# Out:
# count    500.000000
# mean       1.548000
# std        1.746366
# min       -1.000000
# 25%        0.000000
# 50%        2.000000
# 75%        3.000000
# max        4.000000
# Name: delivery_delay, dtype: float64

# %%
df['is_late'].value_counts(normalize=True) * 100
# Out:
# is_late
# 1    67.2
# 0    32.8
# Name: proportion, dtype: float64

# %%
df.columns
# Out:
# Index(['Order Id', 'Type', 'Order Status', 'order_date', 'shipping_date',
#        'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'delivery_delay', 'is_late', 'Delivery Status', 'Late_delivery_risk',
#        'Shipping Mode', 'Sales', 'Order Item Quantity', 'Order Item Discount',
#        'Order Item Discount Rate', 'Order Item Product Price',
#        'Order Item Profit Ratio', 'Order Profit Per Order',
#        'Benefit per order', 'profit_margin', 'Product Name', 'Product Price',
#        'Product Status', 'Category Name', 'Department Name', 'Customer Id',
#        'Customer Segment', 'Customer City', 'Customer State',
#        'Customer Country', 'Market', 'Order Region', 'Order Country',
#        'Order City', 'Order State'],
#       dtype='object')

# %%
df.groupby('Order Region')['delivery_delay'].mean().sort_values(ascending=False)
# Out:
# Order Region
# Southern Asia      1.989474
# Central America    1.550000
# Western Europe     1.542857
# Eastern US         1.394231
# Western US         1.261364
# Name: delivery_delay, dtype: float64

# %%
df.groupby('Shipping Mode')['delivery_delay'].mean()
# Out:
# Shipping Mode
# First Class       1.591667
# Same Day          1.818898
# Second Class      1.422222
# Standard Class    1.355932
# Name: delivery_delay, dtype: float64

# %%
df[df['Order Profit Per Order'] < 0]
# Out:
#      Order Id      Type Order Status  order_date shipping_date  \
# 18         19  TRANSFER      PENDING  2016-10-25    2016-10-29
# 20         21     DEBIT      ON_HOLD  2016-10-23    2016-10-29
# 29         30  TRANSFER      PENDING  2017-08-13    2017-08-15
# 30         31   PAYMENT     CANCELED  2015-10-04    2015-10-07
# 42         43     DEBIT       CLOSED  2016-11-12    2016-11-13
# ..        ...       ...          ...         ...           ...
# 477       478  TRANSFER      PENDING  2015-12-15    2015-12-19
# 482       483     DEBIT     CANCELED  2015-04-09    2015-04-14
# 485       486   PAYMENT      PENDING  2015-04-26    2015-05-03
# 491       492  TRANSFER       CLOSED  2015-06-10    2015-06-15
# 494       495  TRANSFER     CANCELED  2015-05-08    2015-05-17
#
#      Days for shipping (real)  Days for shipment (scheduled)  delivery_delay  \
# 18                          4                              5              -1
# ...

# %%
df.groupby('Product Name')[['Sales','Order Profit Per Order']].sum().sort_values(by='Sales', ascending=False)
# Out:
#                 Sales  Order Profit Per Order
# Product Name
# Product WBGR  1998.72                  606.65
# Product EPTC  1992.74                  374.79
# Product SCVK  1986.81                  677.19
# Product XLCR  1984.42                  469.69
# Product WMWO  1983.12                  -91.38
# ...               ...                     ...
# Product ATIY     0.00                   23.74
# Product HQPD     0.00                  -65.52
# Product KTTZ     0.00                  -32.79
# Product GOFZ     0.00                   30.73
# Product DSLA     0.00                   14.47
#
# [500 rows x 2 columns]

# %%
on_time_rate = (df['is_late'] == 0).mean() * 100

# %%
late_rate = (df['is_late'] == 1).mean() * 100

# %%
avg_delay = df['delivery_delay'].mean()

# %%
profit_margin = (df['Order Profit Per Order'].sum() / df['Sales'].sum()) * 100

# %%
revenue_at_risk = df[df['is_late'] == 1]['Sales'].sum()

# %%
df.groupby('Shipping Mode')['is_late'].mean() * 100
# Out:
# Shipping Mode
# First Class       69.166667
# Same Day          70.866142
# Second Class      65.185185
# Standard Class    63.559322
# Name: is_late, dtype: float64
